# %% [markdown]
# <a href="https://colab.research.google.com/github/pasyaalv/PembelajaranMesin/blob/main/Quiz_2_Praktikum_Pembelajaran_Mesin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/pasyaalv/PembelajaranMesin/main/covid_19_indonesia_time_series_all.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#        Date Location ISO Code     Location  New Cases  New Deaths  \
# 0  3/1/2020             ID-JK  DKI Jakarta          2           0
# 1  3/2/2020             ID-JK  DKI Jakarta          2           0
# 2  3/2/2020               IDN    Indonesia          2           0
# 3  3/2/2020             ID-RI         Riau          1           0
# 4  3/3/2020             ID-JK  DKI Jakarta          2           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
# 2              0                 2            2             0
# 3              0                 1            2             0
# 4              0                 2           43            20
#
#    Total Recovered  ...  Latitude New Cases per Million  \
# 0               41  ... -6.204699                  0.18
# 1               41  ... -6.204699                  0.18
# ...

# %%
print(df.dtypes)
# Out:
# Date                            object
# Location ISO Code               object
# Location                        object
# New Cases                        int64
# New Deaths                       int64
# New Recovered                    int64
# New Active Cases                 int64
# Total Cases                      int64
# Total Deaths                     int64
# Total Recovered                  int64
# Total Active Cases               int64
# Location Level                  object
# City or Regency                float64
# Province                        object
# Country                         object
# Continent                       object
# Island                          object
# Time Zone                       object
# Special Status                  object
# Total Regencies                  int64
# Total Cities                   float64
# Total Districts                  int64
# Total Urban Villages           float64
# Total Rural Villages           float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21759 entries, 0 to 21758
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         21759 non-null  object
#  1   Location ISO Code            21759 non-null  object
#  2   Location                     21759 non-null  object
#  3   New Cases                    21759 non-null  int64
#  4   New Deaths                   21759 non-null  int64
#  5   New Recovered                21759 non-null  int64
#  6   New Active Cases             21759 non-null  int64
#  7   Total Cases                  21759 non-null  int64
#  8   Total Deaths                 21759 non-null  int64
#  9   Total Recovered              21759 non-null  int64
#  10  Total Active Cases           21759 non-null  int64
#  11  Location Level               21759 non-null  object
#  12  City or Regency              0 non-null      float64
# ...

# %%
df.describe()
# Out:
#           New Cases    New Deaths  New Recovered  New Active Cases  \
# count  21759.000000  21759.000000   21759.000000      21759.000000
# mean     391.293580     13.220415     377.310998          0.762167
# std     2074.551043     76.482617    1999.062563        937.213509
# min        0.000000      0.000000       0.000000     -25725.000000
# 25%        7.000000      0.000000       4.000000        -16.000000
# 50%       41.000000      1.000000      31.000000          0.000000
# 75%      151.000000      5.000000     143.000000         27.000000
# max    56757.000000   2069.000000   48832.000000      36726.000000
#
#         Total Cases   Total Deaths  Total Recovered  Total Active Cases  \
# count  2.175900e+04   21759.000000     2.175900e+04        21759.000000
# mean   8.525997e+04    2648.289352     7.671260e+04         5899.079002
# std    3.685133e+05   11776.011067     3.403957e+05        27518.102431
# min    1.000000e+00       0.000000     0.000000e+00        -2306.000000
# ...

# %%
df.count()
# Out:
# Date                           21759
# Location ISO Code              21759
# Location                       21759
# New Cases                      21759
# New Deaths                     21759
# New Recovered                  21759
# New Active Cases               21759
# Total Cases                    21759
# Total Deaths                   21759
# Total Recovered                21759
# Total Active Cases             21759
# Location Level                 21759
# City or Regency                    0
# Province                       21117
# Country                        21759
# Continent                      21759
# Island                         21117
# Time Zone                      21117
# Special Status                  3123
# Total Regencies                21759
# Total Cities                   21145
# Total Districts                21759
# Total Urban Villages           21142
# Total Rural Villages           21117
# Area (km2)                     21759
# ...

# %%
df.describe(include='all')
# Out:
#              Date Location ISO Code     Location     New Cases    New Deaths  \
# count       21759             21759        21759  21759.000000  21759.000000
# unique        643                35           35           NaN           NaN
# top     1/16/2021             ID-JK  DKI Jakarta           NaN           NaN
# freq           35               642          642           NaN           NaN
# mean          NaN               NaN          NaN    391.293580     13.220415
# std           NaN               NaN          NaN   2074.551043     76.482617
# min           NaN               NaN          NaN      0.000000      0.000000
# 25%           NaN               NaN          NaN      7.000000      0.000000
# 50%           NaN               NaN          NaN     41.000000      1.000000
# 75%           NaN               NaN          NaN    151.000000      5.000000
# max           NaN               NaN          NaN  56757.000000   2069.000000
#
# ...

# %%
df.fillna(0)
# Out:
#             Date Location ISO Code          Location  New Cases  New Deaths  \
# 0       3/1/2020             ID-JK       DKI Jakarta          2           0
# 1       3/2/2020             ID-JK       DKI Jakarta          2           0
# 2       3/2/2020               IDN         Indonesia          2           0
# 3       3/2/2020             ID-RI              Riau          1           0
# 4       3/3/2020             ID-JK       DKI Jakarta          2           0
# ...          ...               ...               ...        ...         ...
# 21754  12/2/2021             ID-SA    Sulawesi Utara          2           0
# 21755  12/2/2021             ID-SB    Sumatera Barat          4           0
# 21756  12/2/2021             ID-SS  Sumatera Selatan          4           0
# 21757  12/2/2021             ID-SU    Sumatera Utara          4           0
# 21758  12/3/2021               IDN         Indonesia        245           8
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21759 entries, 0 to 21758
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         21759 non-null  object
#  1   Location ISO Code            21759 non-null  object
#  2   Location                     21759 non-null  object
#  3   New Cases                    21759 non-null  int64
#  4   New Deaths                   21759 non-null  int64
#  5   New Recovered                21759 non-null  int64
#  6   New Active Cases             21759 non-null  int64
#  7   Total Cases                  21759 non-null  int64
#  8   Total Deaths                 21759 non-null  int64
#  9   Total Recovered              21759 non-null  int64
#  10  Total Active Cases           21759 non-null  int64
#  11  Location Level               21759 non-null  object
#  12  City or Regency              0 non-null      float64
# ...

# %%
df['New Cases'] = df['New Cases'].fillna(0)
df['New Deaths'] = df['New Deaths'].fillna(0)
df['New Recovered'] = df['New Recovered'].fillna(0)
df['New Active Cases'] = df['New Active Cases'].fillna(0)
df['Total Cases'] = df['Total Cases'].fillna(0)
df['Total Deaths'] = df['Total Deaths'].fillna(0)
df['Total Recovered'] = df['Total Recovered'].fillna(0)
df['Total Active Cases'] = df['Total Active Cases'].fillna(0)
df['City or Regency'] = df['City or Regency'].fillna(0)
df['Total Regencies'] = df['Total Regencies'].fillna(0)
df['Total Cities'] = df['Total Cities'].fillna(0)
df['Total Districts'] = df['Total Districts'].fillna(0)
df['Total Urban Villages'] = df['Total Urban Villages'].fillna(0)
df['Total Rural Villages'] = df['Total Rural Villages'].fillna(0)
df['Area (km2)'] = df['Area (km2)'].fillna(0)
df['Population'] = df['Population'].fillna(0)
df['Population Density'] = df['Population Density'].fillna(0)
df['Longitude'] = df['Longitude'].fillna(0)
df['Latitude'] = df['Latitude'].fillna(0)
df['New Cases per Million'] = df['New Cases per Million'].fillna(0)
df['Total Cases per Million'] = df['Total Cases per Million'].fillna(0)
df['New Deaths per Million'] = df['New Deaths per Million'].fillna(0)
df['Total Deaths per Million'] = df['Total Deaths per Million'].fillna(0)
df['Total Deaths per 100rb'] = df['Total Deaths per 100rb'].fillna(0)
df['Growth Factor of New Cases'] = df['Growth Factor of New Cases'].fillna(0)
df['Growth Factor of New Deaths'] = df['Growth Factor of New Deaths'].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21759 entries, 0 to 21758
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         21759 non-null  object
#  1   Location ISO Code            21759 non-null  object
#  2   Location                     21759 non-null  object
#  3   New Cases                    21759 non-null  int64
#  4   New Deaths                   21759 non-null  int64
#  5   New Recovered                21759 non-null  int64
#  6   New Active Cases             21759 non-null  int64
#  7   Total Cases                  21759 non-null  int64
#  8   Total Deaths                 21759 non-null  int64
#  9   Total Recovered              21759 non-null  int64
#  10  Total Active Cases           21759 non-null  int64
#  11  Location Level               21759 non-null  object
#  12  City or Regency              21759 non-null  float64
# ...

# %%
df.describe(include='all')
# Out:
#              Date Location ISO Code     Location     New Cases    New Deaths  \
# count       21759             21759        21759  21759.000000  21759.000000
# unique        643                35           35           NaN           NaN
# top     1/16/2021             ID-JK  DKI Jakarta           NaN           NaN
# freq           35               642          642           NaN           NaN
# mean          NaN               NaN          NaN    391.293580     13.220415
# std           NaN               NaN          NaN   2074.551043     76.482617
# min           NaN               NaN          NaN      0.000000      0.000000
# 25%           NaN               NaN          NaN      7.000000      0.000000
# 50%           NaN               NaN          NaN     41.000000      1.000000
# 75%           NaN               NaN          NaN    151.000000      5.000000
# max           NaN               NaN          NaN  56757.000000   2069.000000
#
# ...

# %%
df.corr()
# Out:
#                              New Cases  New Deaths  New Recovered  \
# New Cases                     1.000000    0.883605       0.896256
# New Deaths                    0.883605    1.000000       0.937687
# New Recovered                 0.896256    0.937687       1.000000
# New Active Cases              0.229723   -0.125791      -0.225616
# Total Cases                   0.558409    0.591411       0.630925
# Total Deaths                  0.488417    0.552839       0.569523
# Total Recovered               0.510819    0.546664       0.587108
# Total Active Cases            0.950248    0.921230       0.942956
# City or Regency                    NaN         NaN            NaN
# Total Regencies               0.523871    0.485562       0.524084
# Total Cities                  0.532138    0.489620       0.532518
# Total Districts               0.527537    0.489060       0.527747
# Total Urban Villages          0.529561    0.489882       0.529831
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

korelasi = df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(korelasi[(korelasi >= 0.5) | (korelasi <= -0.4)], cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1, 
            annot=True, annot_kws={"size": 8}, square=True).set_title('Korelasi Antar Variabel')
plt.show()

# %%
case_total = df.groupby("Location")["Total Cases per Million"].sum().sort_values()
case_total.plot(kind="barh", fontsize=10, figsize=(8,40), title='Total Kasus yang terjadi di Indonesia')
plt.show()

death_total = df.groupby("Location")["Total Deaths per Million"].sum().sort_values()
death_total.plot(kind="barh", fontsize=10, figsize=(8,40), title='Jumlah Kematian')
plt.show()

# %%
sns.boxplot(df['Total Deaths per 100rb'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Scatter plot
fig, ax = plt.subplots(figsize = (20,20))
ax.scatter(df['Total Cases per Million'], df['Total Deaths per Million'])

# x-axis label
ax.set_xlabel('Jumlah Kasus yang terjadi')
 
# y-axis label
ax.set_ylabel('Jumlah Kematian')
plt.show()
